# %%
import pandas as pd
from pandas_datareader import data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = web.DataReader("GOOG",data_source='yahoo',start='2010-01-01',end='2014-01-01')

# %%
data
# Out:
#                   High         Low  ...    Volume   Adj Close
# Date                                ...
# 2009-12-31  311.532288  308.832428  ...   2448700  308.832428
# 2010-01-04  313.579620  310.954468  ...   3927000  312.204773
# 2010-01-05  312.747742  309.609497  ...   6031900  310.829926
# 2010-01-06  311.761444  302.047852  ...   7987100  302.994293
# 2010-01-07  303.861053  295.218445  ...  12876600  295.940735
# ...                ...         ...  ...       ...         ...
# 2010-12-27  300.762665  298.630646  ...   2425200  300.065277
# 2010-12-28  300.807495  297.888428  ...   2137500  298.341736
# 2010-12-29  300.080231  298.341736  ...   2046000  299.377869
# 2010-12-30  299.542236  297.579590  ...   1986300  298.311859
# 2010-12-31  298.092682  294.909607  ...   3090000  295.875977
#
# [253 rows x 6 columns]

# %%
data.plot()
#legend is there and you can see here only purple line is so much visible because other values are very much less

# %%
data.iloc[:,[0,1,2,3]].plot()
#graph of high low open close

# %%
data.iloc[:,0].plot()
#this is all about the high

# %%
#you can also do this by passing y axis as a column name
data.plot(y='High')

# %%
#another way 
data['High'].plot()

# %%
data[['High','Low']].plot()

# %% [markdown]
# # Modifying Aesthetics

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
data['High'].plot()

# %%
plt.style.use('dark_background')
data['High'].plot()

# %% [markdown]
# # Bar Chart(count)

# %%
def rank_performer(value):
    if value<=200:
        return "Less Than and equal to 200"
    elif value >200 and value<=500:
        return "Greater than 200 and less than or equal to 500 "
    else:
        return "More than 500"
    
a = data['Close'].apply(rank_performer).value_counts()

# %%
a.plot(kind='bar')

# %%
a.plot(kind='barh')

# %%
data['Close'].mean()
# Out:
# 327.7248241041954

# %%
def rank_checker(value):
    if value<327.7248241041954:
        return "Below Average"
    else:
        return "Above Average"
data['Close'].apply(rank_checker).value_counts().plot(kind='pie')

# %%
def rank_checker(value):
    if value<327.7248241041954:
        return "Below Average"
    else:
        return "Above Average"
data['Close'].apply(rank_checker).value_counts().plot(kind='pie',legend = True)

# %%
def buckets(value):
    return int(value/100.0)*100

data['High'].apply(buckets)
# Out:
# Date
# 2009-12-31    300
# 2010-01-04    300
# 2010-01-05    300
# 2010-01-06    300
# 2010-01-07    300
#              ...
# 2013-12-24    500
# 2013-12-26    500
# 2013-12-27    500
# 2013-12-30    500
# 2013-12-31    500
# Name: High, Length: 1007, dtype: int64
