# %% [markdown]
# # GroupBY:
# One of the powerfull feature of Pandas Library.It basically created from a DataFrame and what is does is create essentially grouping or categories that are based on comman values in certain columns or multiple columns.
# Author:Amanpreet Singh(aman64039@gmail.com)

# %%
import pandas as pd

# %%
data = pd.read_csv("datasets/fortune1000.csv")
#this data consist of list of 1000 companies and we have rank of the companies , name ,sector of the company and so on.

data
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# Rank         1000 non-null int64
# Company      1000 non-null object
# Sector       1000 non-null object
# Industry     1000 non-null object
# Location     1000 non-null object
# Revenue      1000 non-null int64
# Profits      1000 non-null int64
# Employees    1000 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
#Rank as index
data.set_index('Rank',inplace=True)

# %%
data
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
"""
The Ideal thing that you want to groupby is always going to be a column that has duplicate value.
This basically mean you want to create a segments of your dataset.For Example there is not any 
point that we are grouping on company because every single vale in company column is unique.
But if we are grouping on sector its make some how sense because companies belong to a sector and
we can see how much unique value is availble in Sector. In sector only 
21 unqiue values are there in 1000 nrecord so we can make group on secotor.
So Sector is exactly perfect for us to Group by and the reason is that because there are multiple 
companies that fall into the exact same sector.Similary Industry is another good column because
multiple companies will fall to same industry as well.

lets have a look on syntax how we can use group by in on sector.

"""
data['Sector'].nunique()
# Out:
# 21

# %%
"""
Sytax is we have to call a method name as groupby which take argument as a column name
on which you want to make a groups.So how is this going to work behind the sence.
Pandas is going to take a look at all of the values in the sector column for example its going 
to start at retail. Its then going to look through the data set and collect all the rows that fall
onto that sector.So after executing the follwing command this is going to be printed.
It will create a pandas dataframe grouo by object.
"""

data.groupby('Sector')

# %%
#now data is dataframe object and sector is groupby object. These 2 are seprtely object of pandas
#you can see
sector = data.groupby('Sector')
print(type(data)) #'pandas.core.frame.DataFrame'
print(type(sector)) #'pandas.core.groupby.generic.DataFrameGroupBy'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
#both will return same output
len(sector)
data["Sector"].nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6dfaa081ca30> in <module>
#       1 len(sector)
#       2 data["Sector"].nunique()
# ----> 3 data["Sector"].unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
#both will return the count of every unique values
sector.size()
data["Sector"].value_counts()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
#will return the very first row  row of each and every sector 
sector.first()
#will return the last row  row of each and every sector 
sector.last()
#the convenience of the first and last methods is to be able to extract just sample rows from
#the top and the end of each grouping that gives us a general sense .
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
#will return a dictionary in which keys will be the secotrs and values will be the list of index where the sector availble

sector.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...
